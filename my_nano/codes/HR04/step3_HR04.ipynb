# %%
#!/usr/bin/env python
"""choose_skies.ipynb: a notebook to look at detected GW skies """

__author__ = "Chiara M. F. Mingarelli"
__copyright__ = "Copyright 2017, GWASAP project"
__credits__ = ["Chiara Mingarelli"]
__license__ = "GPL"
__version__ = "0.0.1"
__maintainer__ = "Chiara Mingarelli"
__email__ = "mingarelli@gmail.com"
__status__ = "prototype"

# %%
from __future__ import division
from IPython.display import display, Math, Latex
import math
from math import sqrt, cos, sin, pi
import numpy as np
import statsmodels.api as sm
from scipy.interpolate import interp1d
import scipy.integrate
import matplotlib.pyplot as plt
import matplotlib.mlab as ml
from matplotlib.ticker import FormatStrFormatter, LinearLocator, NullFormatter, NullLocator, MultipleLocator
import matplotlib.ticker
import matplotlib.colors
from matplotlib.font_manager import FontProperties
from matplotlib import rc, text
import healpy as hp
import plot_mpl2
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.io import fits
import collections
from collections import Counter


# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %%
det_sky = np.genfromtxt("../../detectedSkies/detected_skies_HR04_30dex_100.txt")

# %%
len(det_sky)
# Out:
# 574

# %%
def find_nearest(array,value):
    #returns index of matching value in array
    idx = (np.abs(array-value)).argmin()
    return idx

# %%
def find_gal_idx(nameList, name):
    ans = [i for i, x in enumerate(nameList) if x == name]
    return ans

def find_gal_dec_idx(nameList, dec):
    ans = [i for i, x in enumerate(nameList) if x >= dec]
    return ans

def find_gal_dec_idx_neg(nameList, dec):
    ans = [i for i, x in enumerate(nameList) if x <= dec]
    return ans

# %%
det_DEC = det_sky[:,1]*180/pi

# %%
det_name = np.genfromtxt("../../detectedSkies/detected_skies_HR04_30dex_100.txt", usecols = (6))
det_file = np.genfromtxt("../../detectedSkies/detected_skies_HR04_30dex_100.txt", usecols = (4), dtype=None)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.

# %%
det_name = det_name.tolist()

# %%
len(det_name)
# Out:
# 574

# %%
det_name
# Out:
# [0.45671746811529024,
#  0.28599043619450654,
#  0.46309429060627105,
#  0.9059928151284566,
#  0.488148863961625,
#  0.46774066178188484,
#  0.8623570741500615,
#  0.27624663685988754,
#  0.8276802451546084,
#  0.40213091234620213,
#  0.9410755653450398,
#  0.3793812658188573,
#  0.35990926361656833,
#  0.7141518938376354,
#  0.896993001245504,
#  0.3391717738135984,
#  0.43786611453952123,
#  0.4531848803575096,
#  0.8851321638502788,
#  0.3216743339368666,
#  0.44324161151587516,
#  0.3961538770209884,
#  0.38286906002537574,
#  0.48964021491063736,
#  0.7161350879834503,
#  0.45180456542254743,
#  0.8628354947679509,
#  0.553490064810856,
#  0.5066297847869528,
#  0.6370461934444609,
#  0.39747438276140046,
#  0.8443723198416199,
#  0.39102400046462643,
#  0.3773875733804029,
#  0.5168471389594553,
#  0.34899935113082964,
#  0.6121081030420337,
#  0.38414528328334707,
#  0.5076142098743204,
#  0.7806395953774922,
#  0.2770906021222441,
#  0.5704759798632331,
#  0.8411004835627971,
#  0.9181331868157049,
#  0.7559272299565422,
#  0.9550093197723429,
#  0.3700297425511462,
#  0.9319856689171429,
#  0.7344371503576699,
#  0.28885986850276435,
#  0.25201863509824,
#  0.335802560738503,
#  0.35006558430668844,
#  0.3585146605983098,
#  0.7917586486624633,
#  0.3888612723498721,
#  0.46258088466743197,
#  0.7125692935369918,
#  0.2904664192272939,
#  0.36890270234711153,
#  0.7605531749146706,
#  0.6709535776754475,
#  0.26221348061705874,
#  0.5227571674197864,
#  0.49359383460395106,
#  0.5272705495649216,
#  0.7133601548096086,
#  0.30347633629652954,
#  0.9661975355269938,
#  0.5562598049851427]

# %%
rm_dec_pos = find_gal_dec_idx(det_DEC, 70.0)
rm_dec_neg = find_gal_dec_idx_neg(det_DEC, -70.0)

# %%
# concatenate ±70 deg in declination galaxy indices
all_bad_idx = rm_dec_neg + rm_dec_pos

# %%
new_det_sky = np.delete(det_sky, all_bad_idx ,0)

# %%
new_det_sky_name = np.delete(det_name, all_bad_idx,0)
new_det_sky_file= np.delete(det_file, all_bad_idx,0)

# %%
new_det_sky.shape
# Out:
# (148, 15)

# %%
# Parameters of detected skies once the list has had the bad galaxies removed
det_RA = new_det_sky[:,0]*180/pi
det_DEC = new_det_sky[:,1]*180/pi
det_freq = new_det_sky[:,2]
det_strain = new_det_sky[:,3]
mchirp_rec = new_det_sky[:,5]
q_rec = new_det_sky[:,6]
det_name = new_det_sky_name
det_dist = new_det_sky[:,8]
mstar_list = new_det_sky[:,9]
save_p= new_det_sky[:,10]
det_file = new_det_sky_file

# %%
det_freq
# Out:
# array([3.25357148e-09, 1.64396241e-09, 2.79562214e-09, 2.40213045e-09,
#        3.50995294e-09, 2.40213045e-09, 2.52212011e-08, 6.94655958e-09,
#        5.12868469e-09, 4.40680788e-09, 3.01591718e-09, 3.78653727e-09,
#        6.94655958e-09, 3.50995294e-09, 2.79562214e-09, 1.41257007e-09,
#        4.75406438e-09, 5.12868469e-09, 5.12868469e-09, 6.43915417e-09,
#        5.96881176e-09, 3.01591718e-09, 3.78653727e-09, 1.77350666e-09,
#        3.01591718e-09, 2.22666892e-09, 2.40213045e-09, 1.09500326e-08,
#        2.22666892e-09, 4.08491643e-09, 6.94655958e-09, 5.53282509e-09,
#        2.79562214e-09, 3.25357148e-09, 3.50995294e-09, 3.25357148e-09,
#        5.96881176e-09, 5.96881176e-09, 4.40680788e-09, 5.12868469e-09,
#        3.78653727e-09, 5.53282509e-09, 8.48830202e-08, 3.25357148e-09,
#        3.25357148e-09, 3.50995294e-09, 2.79562214e-09, 1.41257007e-09,
#        2.59141835e-09, 1.41257007e-09, 2.79562214e-09, 1.77350666e-09,
#        2.59141835e-09, 4.75406438e-09, 1.18128953e-08, 5.53282509e-09,
#        1.60000050e-08, 5.12868469e-09, 5.96881176e-09, 4.40680788e-09,
#        4.08491643e-09, 1.41257007e-09, 4.08491643e-09, 2.22666892e-09,
#        6.94655958e-09, 4.75406438e-09, 1.41257007e-09, 4.75406438e-09,
#        2.40213045e-09, 3.78653727e-09, 4.08491643e-09, 2.52212011e-08,
#        4.75406438e-09, 6.43915417e-09, 1.64396241e-09, 5.53282509e-09,
#        2.93526724e-08, 5.53282509e-09, 6.94655958e-09, 6.94655958e-09,
#        3.25357148e-09, 6.43915417e-09, 1.09500326e-08, 4.40680788e-09,
#        2.59141835e-09, 2.72086319e-08, 2.72086319e-08, 2.16712460e-08,
#        3.01591718e-09, 1.09500326e-08, 5.53282509e-09, 1.41257007e-09,
#        5.53282509e-09, 8.08447174e-09, 2.06402382e-09, 4.08491643e-09,
#        1.41257007e-09, 3.78653727e-09, 5.96881176e-09, 1.41257007e-09,
#        2.00882887e-08, 2.22666892e-09, 1.41257007e-09, 4.08491643e-09,
#        4.08491643e-09, 2.22666892e-09, 8.72152818e-09, 8.72152818e-09,
#        4.08491643e-09, 2.22666892e-09, 4.75406438e-09, 7.49394853e-09,
#        4.40680788e-09, 3.78653727e-09, 1.09500326e-08, 1.41257007e-09,
#        1.27437515e-08, 2.59141835e-09, 7.49394853e-09, 2.59141835e-09,
#        8.08447174e-09, 6.43915417e-09, 1.64396241e-09, 2.59141835e-09,
#        3.50995294e-09, 1.18128953e-08, 3.50995294e-09, 5.96881176e-09,
#        1.27437515e-08, 3.78653727e-09, 6.94655958e-09, 2.33789404e-08,
#        4.08491643e-09, 2.22666892e-09, 3.50995294e-09, 3.50995294e-09,
#        6.94655958e-09, 1.86209571e-08, 3.25357148e-09, 6.43915417e-09,
#        3.78653727e-09, 8.72152818e-09, 2.22666892e-09, 4.40680788e-09,
#        9.40878467e-09, 3.25357148e-09, 2.16712460e-08, 6.43915417e-09])

# %%
# load pulsar positions on the sky

# %%
p_pos = np.genfromtxt("../pulsar_positions.txt", skip_header=0, usecols = (1,2) )
p_RA = p_pos[:,0]
p_DEC = pi/2-p_pos[:,1]
p_name = np.genfromtxt("../pulsar_positions.txt", skip_header=0, usecols = (0), dtype = 'S13' )

# %%
Mp_pos = np.genfromtxt("../more_pulsars.txt", usecols = (1,2) )
Mp_RA = Mp_pos[:,0]
Mp_DEC = Mp_pos[:,1]
Mp_name = np.genfromtxt("../more_pulsars.txt", usecols = (0), dtype = 'S13' )

# %%
# Make maps of all the detected sources

# %%
# To plot a single sky here, set up for multiple detected skies 

#for ii in range(len(det_RA)):
for ii in range(len(det_RA)):
    scat_sky=np.genfromtxt("../../scatter_maps/scatterData_freq_"+str(det_freq[ii])+"Hz.dat")
    scat_ra = scat_sky[:,0]
    scat_dec = scat_sky[:,1]
    scat_strain = np.log10(scat_sky[:,2])
    #look_up_freq = det_freq[ii]
    ax = plt.subplot(111, projection='astro mollweide')
    colors = scat_strain
    sky=plt.scatter(scat_ra, scat_dec, c = colors, edgecolors='none', cmap ='viridis_r',  rasterized=True)
    #plt.suptitle(str(det_name[ii])+", GW sky at $f=$ "+str('%.2e' %det_freq[ii])+" Hz, $h=$"+str('%.2e'%det_strain[ii]),\
    #             y=0.3)
    plt.suptitle(r"$\log_{10}(h)$, GW sky at $f=$ "+str('%.2e' %det_freq[ii])+" Hz", y=0.3)
    #plt.scatter(Mp_RA*pi/180, Mp_DEC*pi/180, color ='white', marker = "*", alpha=1)
    plt.scatter(p_RA, p_DEC, marker = "*", color = '#ff7f0e', s = 100)
    plt.scatter(det_RA[ii]*pi/180, det_DEC[ii]*pi/180, marker = "*", color = "white", s = 100)


    plt.colorbar(sky, orientation = 'horizontal')
    ax.grid(linewidth=0.5)
    #ax.set_axisbelow(True)

    plt.savefig("plots_hr04_30/herc_skies/"+str(ii)+"_"+str(det_name[ii])+"_wPulsars_test.pdf", dpi=400)


    plt.clf()
    #plt.savefig("allEPTA_pulsars.pdf", dpi=400)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/projections/geo.py:426: RuntimeWarning: invalid value encountered in arcsin
#   theta = np.arcsin(y / np.sqrt(2))

# %% [markdown]
# ## Visually inspect resultant GW skies. Are the sources lying on e.g. interpolation flares?

# %%
# indices of skies which failed 2nd inspection, you need to put these in by hand
sec_insp_idx = [3, 6, 9, 15, 17, 27, 28, 31, 32, 41, 42, 46, 47, 49, 50, 52, 54, 58, 59, 63, 67, 71, \
               76, 77, 82, 85, 86, 87, 89, 100, 101, 102, 109, 115, 116, 121, 125, 128, 131, 133, 143]

# %%
final_sky = np.delete(new_det_sky, sec_insp_idx,0)
final_sky_name = np.delete(new_det_sky_name, sec_insp_idx,0)
final_sky_file = np.delete(new_det_sky_file, sec_insp_idx,0)

# %%
final_sky_file
# Out:
# array([b'HR04_81247.txt', b'HR04_114256.txt', b'HR04_77823.txt',
#        b'HR04_13057.txt', b'HR04_115649.txt', b'HR04_106575.txt',
#        b'HR04_33681.txt', b'HR04_41085.txt', b'HR04_75675.txt',
#        b'HR04_88853.txt', b'HR04_108906.txt', b'HR04_38208.txt',
#        b'HR04_12605.txt', b'HR04_89161.txt', b'HR04_93241.txt',
#        b'HR04_36400.txt', b'HR04_73740.txt', b'HR04_48594.txt',
#        b'HR04_35247.txt', b'HR04_109551.txt', b'HR04_24528.txt',
#        b'HR04_90360.txt', b'HR04_16786.txt', b'HR04_86091.txt',
#        b'HR04_55544.txt', b'HR04_80437.txt', b'HR04_113475.txt',
#        b'HR04_96549.txt', b'HR04_25674.txt', b'HR04_114412.txt',
#        b'HR04_37189.txt', b'HR04_45609.txt', b'HR04_21134.txt',
#        b'HR04_105455.txt', b'HR04_85619.txt', b'HR04_69204.txt',
#        b'HR04_110925.txt', b'HR04_97307.txt', b'HR04_59689.txt',
#        b'HR04_71972.txt', b'HR04_94835.txt', b'HR04_11520.txt',
#        b'HR04_40609.txt', b'HR04_92997.txt', b'HR04_57802.txt',
#        b'HR04_101265.txt', b'HR04_93439.txt', b'HR04_11485.txt',
#        b'HR04_51799.txt', b'HR04_38765.txt', b'HR04_66098.txt',
#        b'HR04_27490.txt', b'HR04_114087.txt', b'HR04_64633.txt',
#        b'HR04_78597.txt', b'HR04_95134.txt', b'HR04_75155.txt',
#        b'HR04_66326.txt', b'HR04_52546.txt', b'HR04_53670.txt',
#        b'HR04_83848.txt', b'HR04_19357.txt', b'HR04_93082.txt',
#        b'HR04_45801.txt', b'HR04_19127.txt', b'HR04_49859.txt',
#        b'HR04_22274.txt', b'HR04_67444.txt', b'HR04_84176.txt',
#        b'HR04_12630.txt', b'HR04_61365.txt', b'HR04_58386.txt',
#        b'HR04_15763.txt', b'HR04_78973.txt', b'HR04_45370.txt',
#        b'HR04_96283.txt', b'HR04_36739.txt', b'HR04_109289.txt',
#        b'HR04_111290.txt', b'HR04_45038.txt', b'HR04_67748.txt',
#        b'HR04_29475.txt', b'HR04_94889.txt', b'HR04_19906.txt',
#        b'HR04_40962.txt', b'HR04_30460.txt', b'HR04_40193.txt',
#        b'HR04_59009.txt', b'HR04_27803.txt', b'HR04_42936.txt',
#        b'HR04_52967.txt', b'HR04_14098.txt', b'HR04_23152.txt',
#        b'HR04_72842.txt', b'HR04_26510.txt', b'HR04_20288.txt',
#        b'HR04_89754.txt', b'HR04_46944.txt', b'HR04_104835.txt',
#        b'HR04_51695.txt', b'HR04_92512.txt', b'HR04_10388.txt',
#        b'HR04_110427.txt', b'HR04_15469.txt', b'HR04_97507.txt',
#        b'HR04_78593.txt', b'HR04_14596.txt'], dtype='|S15')

# %%
det_RA = []
det_DEC = []
det_freq = []
det_strain = []
mchirp_rec = []
q_rec = []
det_name = []
det_dist = []
mstar_list = []
save_p= []
det_file = final_sky_file

# %%
for file in final_sky_file:
    
    filename = "../../rusty_data/HR04_Reg/30_dex/"+str(str(file))[2:-1]

    
    
    print(filename)
    det_RA= np.hstack((det_RA , (np.genfromtxt(filename, usecols = (0))*180/pi)))
    det_DEC = np.hstack((det_DEC, (np.genfromtxt(filename, usecols = (1))*180/pi)))
    det_freq= np.hstack((det_freq, np.genfromtxt(filename, usecols = (2))))
    det_strain =np.hstack((det_strain , np.genfromtxt(filename, usecols = (3))))
    mchirp_rec = np.hstack((mchirp_rec, np.genfromtxt(filename, usecols = (4))))
    q_rec = np.hstack((q_rec, np.genfromtxt(filename, usecols = (5))))
    det_name = np.hstack((det_name, np.genfromtxt(filename, usecols = (6), dtype=None)))
    det_dist = np.hstack((det_dist ,np.genfromtxt(filename, usecols = (7))))
    mstar_list = np.hstack((mstar_list, np.genfromtxt(filename, usecols = (8))))
    save_p = np.hstack((save_p, np.genfromtxt(filename, usecols = (9))))
    #det_file = final_sky_file
# Out:
# ../../rusty_data/HR04_Reg/30_dex/HR04_81247.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_114256.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_77823.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_13057.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_115649.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_106575.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_33681.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_41085.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_75675.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_88853.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_108906.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_38208.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_12605.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_89161.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_93241.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_36400.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_73740.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_48594.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_35247.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_109551.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_24528.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_90360.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_16786.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_86091.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_55544.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_80437.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_113475.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_96549.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_25674.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_114412.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_37189.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_45609.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_21134.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_105455.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_85619.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_69204.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_110925.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_97307.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_59689.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_71972.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_94835.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_11520.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_40609.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_92997.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_57802.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_101265.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_93439.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_11485.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_51799.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_38765.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_66098.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_27490.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_114087.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_64633.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_78597.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_95134.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_75155.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_66326.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_52546.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_53670.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_83848.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_19357.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_93082.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_45801.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_19127.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_49859.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_22274.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_67444.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_84176.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_12630.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_61365.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_58386.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_15763.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_78973.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_45370.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_96283.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_36739.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_109289.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_111290.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_45038.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_67748.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_29475.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_94889.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_19906.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_40962.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_30460.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_40193.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_59009.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_27803.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_42936.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_52967.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_14098.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_23152.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_72842.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_26510.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_20288.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_89754.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_46944.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_104835.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_51695.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_92512.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_10388.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_110427.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_15469.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_97507.txt
# ../../rusty_data/HR04_Reg/30_dex/HR04_78593.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ../../rusty_data/HR04_Reg/30_dex/HR04_14596.txt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.

# %%
def hist_weight(lst):
    return np.ones_like(lst)/len(lst)

def auto_bin(bin_size, min_edge, max_edge):
    #bin_size = 0.05; min_edge = -3.5; max_edge = -1
    N = (max_edge-min_edge)/bin_size; Nplus1 = N + 1
    bin_list = np.linspace(min_edge, max_edge, Nplus1)
    return bin_list

# %%
# What is the distribution of frequencies where sources were detected?
#bin_size = 0.1; min_edge = -9.0; max_edge = -8
bin_list = auto_bin(0.1,-9,-8)
weights = hist_weight(np.log10(det_freq))
plt.hist(np.log10(det_freq),bin_list, align='left',  alpha=0.8, edgecolor = 'black', weights = weights)
plt.xlabel(r"Distribution of $\log_{10}(f_\mathrm{GW})$ detected (Hz)")
plt.ylabel("Probability")
plt.legend(frameon=False)
plt.tight_layout()

plt.savefig("plots_hr04_30/step_3/distribution_freq_hr04_30.pdf")
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   import sys
# No handles with labels found to put in legend.

# %%
det_dist = det_dist.tolist()

# %%
fig = plt.figure()

bin_list = auto_bin(10,10,225)
weights = hist_weight(det_dist)
ax = fig.add_subplot(111)
plt.hist(det_dist, bin_list, weights=weights, alpha = 0.8, align='left', edgecolor = 'black')
majorLocator = MultipleLocator(25)
minorLocator = MultipleLocator(5)
ax.xaxis.set_minor_locator(minorLocator)
ax.xaxis.set_major_locator(majorLocator)
plt.xlabel("Distance to Galaxy (Mpc)")
plt.ylabel("Probability")
plt.legend(frameon=False)
plt.tight_layout()

plt.savefig("plots_hr04_30/step_3/distribution_dist_hr04_30.pdf")
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   import sys
# No handles with labels found to put in legend.

# %%
catalog_list = det_name.tolist()

# %%
len(catalog_list)
catalog_list
# Out:
# [b'0.45671746811529024',
#  b'0.28599043619450654',
#  b'0.488148863961625',
#  b'0.3793812658188573',
#  b'0.35990926361656833',
#  b'0.4531848803575096',
#  b'0.8851321638502788',
#  b'0.8628354947679509',
#  b'0.6370461934444609',
#  b'0.39102400046462643',
#  b'0.5168471389594553',
#  b'0.6121081030420337',
#  b'0.776968053277438',
#  b'0.34987148172959076',
#  b'0.2569586140328962',
#  b'0.9571303738933914',
#  b'0.32105050529273127',
#  b'0.2760934650357127',
#  b'0.8383061449463265',
#  b'0.7002282535487325',
#  b'0.5576498683053652',
#  b'0.2606186083995443',
#  b'0.3975846233905186',
#  b'0.7247257706642841',
#  b'UGC06250',
#  b'PGC008317',
#  b'PGC149796',
#  b'PGC170010',
#  b'PGC1524436',
#  b'PGC158976',
#  b'IC1193',
#  b'PGC2647870',
#  b'IC1806',
#  b'PGC044971',
#  b'PGC3098584',
#  b'PGC072717',
#  b'PGC088253',
#  b'ESO324-028',
#  b'PGC018237',
#  b'NGC2492',
#  b'PGC060047',
#  b'NGC5575',
#  b'PGC1388114',
#  b'UGC05361',
#  b'PGC053110',
#  b'IC1153',
#  b'PGC166041',
#  b'PGC088269',
#  b'IC3327',
#  b'6dFJ0628425-2',
#  b'IC1392',
#  b'PGC020721',
#  b'IC1676',
#  b'PGC147475',
#  b'ESO432-010',
#  b'ESO509-015',
#  b'PGC063933',
#  b'PGC018421',
#  b'PGC048974',
#  b'PGC3090831',
#  b'PGC947770',
#  b'ESO205-013',
#  b'2MASXJ0018340',
#  b'IC1894',
#  b'PGC143044',
#  b'PGC005262',
#  b'PGC1109100',
#  b'UGC00580',
#  b'UGC08704',
#  b'UGC03957',
#  b'PGC043967',
#  b'PGC2800969',
#  b'IC5139',
#  b'IC1065',
#  b'PGC181313',
#  b'ESO035-011',
#  b'ESO325-040',
#  b'ESO254-017',
#  b'UGC00072',
#  b'PGC020974',
#  b'NGC6127',
#  b'ESO443-052',
#  b'NGC4645A',
#  b'PGC009570',
#  b'ESO533-035',
#  b'NGC3406',
#  b'ESO383-076',
#  b'ESO316-044',
#  b'PGC051985',
#  b'PGC052242',
#  b'IC1549',
#  b'PGC799485',
#  b'PGC035783',
#  b'PGC064855',
#  b'NGC6375',
#  b'PGC047626',
#  b'ESO251-021',
#  b'NGC7539',
#  b'UGC11202',
#  b'UGC00266',
#  b'PGC069378',
#  b'PGC002055',
#  b'PGC057200',
#  b'PGC016867',
#  b'NGC5463',
#  b'ESO112-008A',
#  b'NGC3615',
#  b'PGC090395',
#  b'PGC1427390',
#  b'PGC130318',
#  b'PGC3097003',
#  b'PGC061374',
#  b'PGC098947',
#  b'PGC1305248',
#  b'UGC05291',
#  b'NGC2994',
#  b'NGC5784',
#  b'PGC996639',
#  b'PGC540133',
#  b'PGC134589',
#  b'ESO289-015',
#  b'NGC6311',
#  b'NGC1322',
#  b'PGC054857',
#  b'IC1062',
#  b'PGC129655',
#  b'ESO365-029',
#  b'IC1212',
#  b'PGC047017',
#  b'ESO268-023',
#  b'PGC023584',
#  b'PGC009507',
#  b'ESO435-003',
#  b'ESO510-048',
#  b'IC0103',
#  b'ESO510-010',
#  b'PGC166317',
#  b'PGC013199',
#  b'PGC029788',
#  b'PGC207841',
#  b'NGC1294',
#  b'PGC035947',
#  b'IC2465',
#  b'PGC061761',
#  b'PGC067982',
#  b'UGC10115',
#  b'PGC028697',
#  b'PGC053394',
#  b'NGC4006',
#  b'ESO483-009',
#  b'UGC02348',
#  b'PGC1499879',
#  b'UGC10662',
#  b'2MASXJ2131552',
#  b'PGC1096277',
#  b'PGC254458',
#  b'NGC0867',
#  b'IC1079',
#  b'PGC3097082',
#  b'ESO373-003',
#  b'PGC029502',
#  b'PGC130518',
#  b'PGC101257',
#  b'PGC050691',
#  b'PGC032197',
#  b'ESO434-018',
#  b'NGC3298',
#  b'PGC021570',
#  b'UGC03803',
#  b'NGC3919',
#  b'PGC054700',
#  b'PGC1541581',
#  b'UGC03646',
#  b'PGC600770',
#  b'PGC299047',
#  b'PGC025156',
#  b'PGC020498',
#  b'NGC0118',
#  b'PGC077679',
#  b'ESO138-029',
#  b'PGC1517888',
#  b'PGC900797',
#  b'PGC052758',
#  b'PGC057733',
#  b'PGC154512',
#  b'PGC130016',
#  b'UGC03800',
#  b'PGC064091',
#  b'NGC7197',
#  b'ESO461-007',
#  b'PGC192446',
#  b'IC0670',
#  b'IC0780',
#  b'ESO397-019',
#  b'PGC055819',
#  b'NGC6812',
#  b'PGC071164',
#  b'PGC129130',
#  b'PGC085093',
#  b'NGC1221',
#  b'PGC939802',
#  b'ESO518-002',
#  b'PGC065571',
#  b'PGC032127',
#  b'PGC043938',
#  b'PGC130936',
#  b'PGC046187',
#  b'2MASXJ1538335',
#  b'ESO317-014',
#  b'ESO237-035',
#  b'PGC051063',
#  b'PGC028786',
#  b'PGC056435',
#  b'PGC156040',
#  b'PGC032955',
#  b'ESO216-005',
#  b'PGC2318158',
#  b'ESO307-010',
#  b'UGC00959',
#  b'PGC069884',
#  b'PGC030665',
#  b'PGC148495',
#  b'PGC3097104',
#  b'PGC100091',
#  b'NGC3309',
#  b'NGC7652',
#  b'PGC036495',
#  b'PGC1125670',
#  b'NGC5044',
#  b'PGC033440',
#  b'NGC4650',
#  b'PGC028404',
#  b'PGC054143',
#  b'UGC03023',
#  b'ESO342-038',
#  b'PGC3081678',
#  b'PGC131855',
#  b'UGC02263',
#  b'6dFJ0855113-2',
#  b'PGC200308',
#  b'PGC009202',
#  b'ESO017-004',
#  b'PGC037785',
#  b'PGC070970',
#  b'IC2601',
#  b'NGC7272',
#  b'ESO053-020',
#  b'PGC242280',
#  b'NGC6319',
#  b'PGC085663',
#  b'PGC1109773',
#  b'PGC055231',
#  b'PGC160573',
#  b'NGC1108',
#  b'NGC7792',
#  b'PGC066051',
#  b'NGC5945',
#  b'ESO509-082',
#  b'PGC431994',
#  b'PGC022299',
#  b'PGC032092',
#  b'NGC6034',
#  b'PGC024988',
#  b'ESO510-073',
#  b'2MASXJ1630157',
#  b'PGC058777',
#  b'ESO264-024',
#  b'NGC5217',
#  b'NGC5251',
#  b'PGC017233',
#  b'ESO509-003',
#  b'NGC7469',
#  b'PGC047335',
#  b'NGC1031',
#  b'PGC071956',
#  b'ESO567-044',
#  b'PGC023414',
#  b'NGC5791',
#  b'ESO510-010',
#  b'PGC1499879',
#  b'ESO436-027',
#  b'PGC165943',
#  b'PGC052242',
#  b'PGC014713',
#  b'2MASXJ0544189',
#  b'IC1366',
#  b'2MASXJ0056014',
#  b'PGC015126',
#  b'NGC5209',
#  b'6dFJ1715223-6',
#  b'PGC044316',
#  b'PGC839829',
#  b'UGC04702',
#  b'NGC5995',
#  b'PGC717099',
#  b'PGC017267',
#  b'2MASXJ0521217',
#  b'PGC1251423',
#  b'PGC066310',
#  b'ESO386-011',
#  b'PGC093971',
#  b'NGC6419',
#  b'NGC2746',
#  b'UGC00741',
#  b'ESO484-002',
#  b'PGC059747',
#  b'NGC0484',
#  b'2MASXJ1024561',
#  b'PGC045031',
#  b'PGC019226',
#  b'PGC143091',
#  b'PGC064983',
#  b'PGC019219',
#  b'NGC7130',
#  b'UGC09640',
#  b'IC1846',
#  b'PGC903906',
#  b'NGC7308',
#  b'PGC015493',
#  b'IC2225',
#  b'PGC022220',
#  b'PGC033568',
#  b'UGC06322',
#  b'PGC075858',
#  b'ESO349-018',
#  b'ESO536-002',
#  b'2MASXJ2235476',
#  b'PGC071469',
#  b'PGC101259',
#  b'PGC130061',
#  b'PGC2801566',
#  b'ESO234-072',
#  b'PGC061805',
#  b'PGC071999',
#  b'ESO013-012',
#  b'PGC058539',
#  b'PGC051063',
#  b'PGC2055576',
#  b'NGC7469',
#  b'PGC000160',
#  b'PGC056055',
#  b'PGC035947',
#  b'ESO184-071',
#  b'PGC047113',
#  b'NGC0432',
#  b'PGC060191',
#  b'PGC056793',
#  b'PGC228417',
#  b'UGC10579',
#  b'NGC5171',
#  b'PGC052776',
#  b'PGC051993',
#  b'PGC2793346',
#  b'PGC213257',
#  b'PGC2086397',
#  b'PGC015991',
#  b'PGC2832016',
#  b'PGC004167',
#  b'PGC129604',
#  b'PGC032092',
#  b'ESO048-021',
#  b'PGC021577',
#  b'PGC161036',
#  b'IC1334',
#  b'NGC2456',
#  b'NGC0507',
#  b'ESO386-002',
#  b'IC1347',
#  b'PGC1050640',
#  b'PGC029098',
#  b'PGC026250',
#  b'PGC1033661',
#  b'NGC2809',
#  b'ESO484-033',
#  b'PGC033963',
#  b'PGC033363',
#  b'NGC7335',
#  b'ESO345-011',
#  b'ESO239-002',
#  b'IC1392',
#  b'PGC1140103',
#  b'NGC0080',
#  b'PGC062531',
#  b'ESO598-022',
#  b'PGC435025',
#  b'NGC7808',
#  b'UGC02263',
#  b'NGC5567',
#  b'PGC019565',
#  b'PGC1709717',
#  b'PGC665864',
#  b'ESO318-002',
#  b'ESO443-028',
#  b'PGC024946',
#  b'PGC1026967',
#  b'ESO424-033',
#  b'PGC016583',
#  b'ESO187-021',
#  b'PGC020107',
#  b'IC1806',
#  b'PGC072956',
#  b'NGC6812',
#  b'IC0944',
#  b'PGC060314',
#  b'PGC003785',
#  b'PGC795305',
#  b'UGC06068',
#  b'PGC014622',
#  b'NGC7527',
#  b'PGC032469',
#  b'PGC011703',
#  b'PGC684268',
#  b'PGC129086',
#  b'PGC036207',
#  b'PGC061084',
#  b'ESO506-027',
#  b'PGC027565',
#  b'PGC018104',
#  b'PGC170029',
#  b'ESO193-026',
#  b'PGC2373130',
#  b'PGC3090387',
#  b'IC0646',
#  b'PGC033934',
#  b'IC0787',
#  b'PGC1570895',
#  b'ESO071-017',
#  b'IC1062',
#  b'PGC034652',
#  b'PGC011443',
#  b'ESO068-005',
#  b'NGC1208',
#  b'NGC6196',
#  b'NGC2398',
#  b'NGC5180',
#  b'PGC052470',
#  b'PGC051119',
#  b'PGC130984',
#  b'PGC995673',
#  b'PGC1020963',
#  b'PGC055932',
#  b'2MASXJ0044201',
#  b'PGC046515',
#  b'PGC055008',
#  b'PGC015338',
#  b'ESO537-012',
#  b'IC0227',
#  b'NGC5629',
#  b'NGC4884',
#  b'PGC059747',
#  b'UGC10693',
#  b'IC0034',
#  b'PGC071465',
#  b'PGC146328',
#  b'PGC001390',
#  b'PGC034855',
#  b'PGC029168',
#  b'NGC3168',
#  b'PGC029871',
#  b'IC4475',
#  b'ESO471-045',
#  b'PGC1663964',
#  b'PGC337502',
#  b'PGC084052',
#  b'PGC056518',
#  b'PGC052870',
#  b'PGC165992',
#  b'PGC067676',
#  b'PGC009100',
#  b'PGC059461',
#  b'PGC057392',
#  b'NGC4692',
#  b'PGC532605',
#  b'ESO292-018',
#  b'PGC989455',
#  b'NGC6075',
#  b'UGC05723',
#  b'NGC7774',
#  b'PGC3091544',
#  b'NGC0511',
#  b'PGC3097003',
#  b'PGC628428',
#  b'PGC086637',
#  b'PGC166342',
#  b'PGC1244529',
#  b'NGC3283',
#  b'PGC174716',
#  b'ESO187-020',
#  b'PGC060107',
#  b'PGC095731',
#  b'PGC147475',
#  b'PGC044545',
#  b'PGC026408',
#  b'UGC08483',
#  b'UGC04478',
#  b'PGC017924',
#  b'PGC054307',
#  b'ESO537-003',
#  b'PGC047727',
#  b'NGC1710',
#  b'UGC01525',
#  b'NGC3385',
#  b'PGC3089287',
#  b'PGC170021',
#  b'NGC0315',
#  b'PGC1985012',
#  b'PGC005466',
#  b'PGC060309',
#  b'ESO477-014',
#  b'NGC1349',
#  b'ESO553-022',
#  b'NGC4172',
#  b'PGC071518',
#  b'PGC098045',
#  b'UGC03021',
#  b'PGC054977',
#  b'PGC1988144',
#  b'IC1163',
#  b'PGC005114',
#  b'PGC345398',
#  b'UGC12890',
#  b'PGC236950',
#  b'ESO237-035',
#  b'PGC073140',
#  b'PGC055220',
#  b'ESO528-036',
#  b'PGC763424',
#  b'PGC1177838',
#  b'PGC2390393',
#  b'ESO366-016',
#  b'PGC002145',
#  b'2MASXJ1835027',
#  b'IC1375',
#  b'ESO424-027',
#  b'PGC860205',
#  b'PGC040543',
#  b'NGC5209',
#  b'NGC3561',
#  b'PGC634698',
#  b'UGC09640',
#  b'PGC057311',
#  b'IC0933',
#  b'UGC10471',
#  b'PGC060985',
#  b'PGC154502',
#  b'PGC133527',
#  b'PGC018792',
#  b'NGC3545B',
#  b'NGC2497',
#  b'2MASXJ0740010',
#  b'UGC04974',
#  b'PGC017086',
#  b'PGC064983',
#  b'PGC814882',
#  b'IC1373',
#  b'PGC025555',
#  b'PGC003277',
#  b'NGC3250',
#  b'NGC4055',
#  b'PGC030079',
#  b'PGC055368',
#  b'UGC05477',
#  b'PGC2832039',
#  b'ESO286-010',
#  b'PGC182715',
#  b'PGC841075',
#  b'ESO122-003',
#  b'PGC069406',
#  b'PGC156980',
#  b'ESO464-005',
#  b'PGC049095',
#  b'NGC7499',
#  b'PGC3090780',
#  b'PGC165538',
#  b'NGC5498',
#  b'PGC1698595',
#  b'NGC4125',
#  b'PGC3089131',
#  b'IC1185',
#  b'PGC128085',
#  b'PGC019386',
#  b'PGC047570',
#  b'PGC064509',
#  b'PGC082006',
#  b'ESO488-024',
#  b'PGC067483',
#  b'PGC080646',
#  b'PGC143044',
#  b'NGC0978',
#  b'ESO579-023',
#  b'NGC4789',
#  b'PGC3097084',
#  b'2MASXJ1011283',
#  b'PGC037801',
#  b'PGC158542',
#  b'PGC016516',
#  b'NGC4335',
#  b'PGC567599',
#  b'PGC3080790',
#  b'PGC053846',
#  b'PGC012044',
#  b'PGC158040',
#  b'PGC1458669',
#  b'2MASXJ0536336',
#  b'ESO478-016',
#  b'PGC2793389',
#  b'NGC0071',
#  b'UGC01306',
#  b'PGC128914',
#  b'UGC10654',
#  b'NGC3873',
#  b'PGC004742',
#  b'PGC006605',
#  b'PGC097958',
#  b'PGC056608',
#  b'PGC006700',
#  b'NGC1239',
#  b'PGC035317',
#  b'PGC272245',
#  b'PGC020645',
#  b'ESO435-003',
#  b'PGC200538',
#  b'NGC4786',
#  b'PGC012872',
#  b'IC0575',
#  b'PGC2419200',
#  b'PGC051910',
#  b'PGC002641',
#  b'NGC2205',
#  b'PGC067586',
#  b'IC4559',
#  b'PGC181803',
#  b'PGC054860',
#  b'NGC7432',
#  b'2MASXJ0436537',
#  b'PGC039499',
#  b'PGC1347752',
#  b'UGC01213',
#  b'NGC1294',
#  b'ESO398-012',
#  b'ESO311-013',
#  b'PGC226927',
#  b'PGC593752',
#  b'PGC028068',
#  b'PGC1557696',
#  b'PGC184200',
#  b'PGC028802',
#  b'ESO509-021',
#  b'PGC022791',
#  b'NGC0232',
#  b'ESO156-031',
#  b'ESO479-002',
#  b'ESO506-028',
#  b'PGC059122',
#  b'2MASXJ1538335',
#  b'PGC147707',
#  b'PGC003305',
#  b'NGC5444',
#  b'IC0061',
#  b'PGC027187',
#  b'UGC10144',
#  b'PGC030995',
#  b'ESO254-024',
#  b'PGC076579',
#  b'PGC641756',
#  b'NGC5482',
#  b'IC1085',
#  b'UGC09412',
#  b'PGC009449',
#  b'PGC060243',
#  b'PGC064299',
#  b'ESO383-022',
#  b'PGC022494',
#  b'IC0807',
#  b'PGC020895',
#  b'PGC151103',
#  b'PGC027107',
#  b'2MASXJ2018466',
#  b'NGC6279',
#  b'ESO115-008',
#  b'PGC128784',
#  b'PGC005079',
#  b'PGC052200',
#  b'PGC2054191',
#  b'PGC059698',
#  b'PGC828920',
#  b'NGC4645A',
#  b'PGC047890',
#  b'PGC069884',
#  b'PGC065591',
#  b'PGC083666',
#  b'PGC012953',
#  b'NGC7034',
#  b'PGC369209',
#  b'ESO264-042',
#  b'PGC1396460',
#  b'PGC225401',
#  b'UGC00881',
#  b'ESO364-040',
#  b'ESO251-026',
#  b'IC1835',
#  b'NGC4782',
#  b'NGC5620',
#  b'PGC2165924',
#  b'PGC1528459',
#  b'NGC7649',
#  b'PGC1370486',
#  b'2MASXJ1326221',
#  b'UGC00227',
#  b'UGC09863',
#  b'PGC628428',
#  b'PGC093999',
#  b'PGC063852',
#  b'PGC170039',
#  b'2MASXJ0438292',
#  b'PGC018182',
#  b'PGC008687',
#  b'PGC021599',
#  b'NGC5171',
#  b'ESO342-027',
#  b'IC4429',
#  b'PGC063870',
#  b'ESO340-025',
#  b'NGC0500',
#  b'PGC029168',
#  b'ESO488-024',
#  b'IC1156',
#  b'PGC3076803',
#  b'PGC186790',
#  b'NGC4926',
#  b'NGC0212',
#  b'2MASXJ2235476',
#  b'ESO533-035',
#  b'ESO373-003',
#  b'NGC0813',
#  b'NGC5140',
#  b'PGC035620',
#  b'PGC043531',
#  b'PGC3090387',
#  b'PGC835215',
#  b'NGC0432',
#  b'PGC033398',
#  b'ESO202-043',
#  b'IC1890',
#  b'PGC005466',
#  b'UGC03971',
#  b'IC1027',
#  b'PGC129467',
#  b'ESO507-045',
#  b'NGC3527',
#  b'ESO462-033',
#  b'IC1832',
#  b'PGC038626',
#  b'NGC1572',
#  b'PGC1119812',
#  b'NGC3468',
#  b'PGC012591',
#  b'PGC979067',
#  b'PGC022489',
#  b'PGC3090187',
#  b'PGC003386',
#  b'ESO351-020',
#  b'PGC023150',
#  b'PGC829883',
#  b'NGC3285',
#  b'PGC135312',
#  b'IC1735',
#  b'PGC013450',
#  b'PGC051985',
#  b'PGC068952',
#  b'PGC699631',
#  b'PGC024059',
#  b'PGC018913',
#  b'PGC058431',
#  b'PGC053846',
#  b'PGC077411',
#  b'ESO384-055',
#  b'PGC015198',
#  b'PGC754626',
#  b'NGC4944',
#  b'PGC031453',
#  b'ESO353-038',
#  b'PGC345398',
#  b'PGC029744',
#  b'NGC2258',
#  b'PGC039543',
#  b'PGC042052',
#  b'NGC4696',
#  b'NGC6163',
#  b'UGC06337',
#  b'PGC044257',
#  b'PGC046605',
#  b'NGC7550',
#  b'PGC128085',
#  b'ESO507-066',
#  b'NGC2943',
#  b'PGC026292',
#  b'NGC5101',
#  b'PGC080665',
#  b'PGC076422',
#  b'PGC000892',
#  b'IC4569',
#  b'PGC071353',
#  b'2MASXJ2023322',
#  b'PGC054253',
#  b'PGC3097985',
#  b'PGC2800918',
#  b'PGC3088405',
#  b'ESO351-011',
#  b'NGC0119',
#  b'ESO510-033',
#  b'PGC1348745',
#  b'PGC035783',
#  b'PGC200396',
#  b'NGC3884',
#  b'PGC000066',
#  b'PGC165613',
#  b'PGC030536',
#  b'ESO207-015',
#  b'PGC1062212',
#  b'PGC044455',
#  b'PGC051473',
#  b'PGC014955',
#  b'PGC1676408',
#  b'2MASXJ1259482',
#  b'PGC056066',
#  b'PGC030150',
#  b'IC4436',
#  b'IC1068',
#  b'2MASXJ1525119',
#  b'PGC1048137',
#  b'PGC047200',
#  b'PGC056786',
#  b'ESO479-011',
#  b'PGC158390',
#  b'PGC682082',
#  b'PGC3097003',
#  b'PGC056035',
#  b'PGC056073',
#  b'UGC00495',
#  b'IC4200',
#  b'SDSSJ015633.0',
#  b'PGC1728823',
#  b'PGC033963',
#  b'PGC023435',
#  b'PGC066830',
#  b'PGC1045350',
#  b'NGC6066',
#  b'PGC699394',
#  b'PGC903906',
#  b'NGC5887',
#  b'PGC034652',
#  b'ESO509-009',
#  b'PGC024951',
#  b'PGC050342',
#  b'IC0942',
#  b'UGC02903',
#  b'PGC068799',
#  b'PGC806584',
#  b'PGC008616',
#  b'PGC030210',
#  b'PGC3087083',
#  b'PGC053846',
#  b'PGC027346',
#  b'PGC014195',
#  b'PGC897464',
#  b'PGC128958',
#  b'2MASXJ0340260',
#  b'PGC000160',
#  b'PGC131459',
#  b'PGC077679',
#  b'NGC0612',
#  b'PGC057128',
#  b'PGC130749',
#  b'PGC044189',
#  b'PGC219696',
#  b'NGC4213',
#  b'UGC04639',
#  b'PGC017033',
#  b'IC3238',
#  b'ESO462-033',
#  b'PGC1031656',
#  b'PGC200396',
#  b'PGC029489',
#  b'2MASXJ0425379',
#  b'PGC170277',
#  ...]

# %%
histo_data = dict((x, catalog_list.count(x)) for x in catalog_list if (catalog_list.count(x) > 12) )

# %%
d= histo_data
print(d)
print(d.values())
# Out:
# {b'NGC6319': 13, b'PGC165677': 13, b'PGC042109': 13, b'PGC006120': 14, b'NGC4472': 26, b'UGC04950': 13}
# dict_values([13, 13, 13, 14, 26, 13])

# %%
X = np.arange(len(d))
fig = plt.figure()
ax = fig.add_subplot(111)
values = list(d.values())
ax.barh(X, values, alpha=0.5, linewidth = 0.5)
ax.set_yticks(X)
#ax.set_yticklabels(large_label)
plt.setp(ax.get_yticklabels(), fontsize=7)
ax.set_yticklabels(d.keys())
majorLocator = MultipleLocator(1)
minorLocator = MultipleLocator(1)
ax.xaxis.set_minor_locator(minorLocator)
ax.xaxis.set_major_locator(majorLocator)
xmax = max(d.values()) + 1
plt.xlim(0, xmax)
plt.xlabel("Count")

plt.savefig("plots_hr04_30/step_3/gal_count_hr04_30.pdf")

plt.show()

# %%
# try using a sorted list

# %%
histo_data = sorted(histo_data.items(), key=lambda x:x[1]) # sort histogram by count

# %%
value = np.zeros([len(histo_data)])
label = []

# %%
for j in range(len(histo_data)):
    value[j] = histo_data[j][1]
    label.append(histo_data[j][0])

# %%
X = np.arange(len(value))
fig = plt.figure()
ax = fig.add_subplot(111)
ax.barh(X, value, alpha=0.5, linewidth = 0.4)
ax.set_yticks(X)
plt.setp(ax.get_yticklabels(), fontsize=7)
ax.set_yticklabels(label)
majorLocator = MultipleLocator(1)
minorLocator = MultipleLocator(1)
ax.xaxis.set_minor_locator(minorLocator)
ax.xaxis.set_major_locator(majorLocator)
#plt.xticks(np.arange(0,4, 1))

plt.savefig("plots_hr04_30/step_3/sorted_gal_count_hr04_30.pdf")

# %%
# Make LaTex tables for paper by adding  & and \\
det_nameR = []
det_distR = []
mstar_listR = []
mchirp_recR = []
q_recR = []
det_freqR = []
det_strainR = []

# %%
# final galaxy list and parameters

det_RA = final_sky[:,0]*180/pi
det_DEC = final_sky[:,1]*180/pi
det_freq = final_sky[:,2]
det_strain = final_sky[:,3]
mchirp_rec = final_sky[:,5]
q_rec = final_sky[:,6]
det_name = final_sky_name
det_dist = final_sky[:,8]
mstar_list = final_sky[:,9]
save_p= final_sky[:,10]
det_file = final_sky_file

# %%
# 34 detected galaxies; add "&" and slashes for latex table 
for ii in range(34):
    det_nameR.append(str(det_name[ii])+str(" & "))
    det_distR.append(str(det_dist[ii])+str(" & "))
    mstar_listR.append(str("%.2f" %mstar_list[ii])+str(" & "))
    mchirp_recR.append(str('%.2e'%mchirp_rec[ii])+str(" & "))
    q_recR.append(str("%.2f" %q_rec[ii])+str(" & "))
    det_freqR.append(str("%.2e" %det_freq[ii])+str(" & "))
    det_strainR.append(str("%.2e" %det_strain[ii])+str(" \\\ "))

# %%
gal_name = []

# %%
for ii in range(len(final_sky_file)):
    sky_q = np.genfromtxt("../../rusty_data/HR04_Reg/30_dex/"+str(str(final_sky_file[ii]))[2:-1], usecols = 5)
    #for qdet in sky_q:
    index = find_nearest(sky_q, q_rec[ii])
    print(sky_q[index])
    gal_name.append(np.genfromtxt("../../rusty_data/HR04_Reg/30_dex/"+str(str(final_sky_file[ii]))[2:-1], usecols = 6, dtype='str')[index])
# Out:
# 0.45671746811529024
# 0.28599043619450654
# 0.488148863961625
# 0.3793812658188573
# 0.35990926361656833
# 0.4531848803575096
# 0.8851321638502788
# 0.8628354947679509
# 0.6370461934444609
# 0.39102400046462643
# 0.5168471389594553
# 0.6121081030420337
# 0.776968053277438
# 0.34987148172959076
# 0.2569586140328962
# 0.9571303738933914
# 0.32105050529273127
# 0.2760934650357127
# 0.8383061449463265
# 0.7002282535487325
# 0.5576498683053652
# 0.2606186083995443
# 0.3975846233905186
# 0.7247257706642841
# 0.5439041296816147
# 0.464251538319313
# 0.4001286138999256
# 0.8151520123098226
# 0.49482729903625755
# 0.48612252122312505
# 0.4672221046792245
# 0.9911651995237096
# 0.6491731946114484
# 0.35279435450874497
# 0.47916276817405795
# 0.8092957631686272
# 0.3499685195612829
# 0.4981316277735455
# 0.6298440709898127
# 0.8490684618472417
# 0.9592561388277182
# 0.43738067762487765
# 0.25617596697649625
# 0.6068685200889518
# 0.3177731672491665
# 0.4365324576511098
# 0.27770601408877377
# 0.25774365216611
# 0.33339007395292336
# 0.9291470178638196
# 0.266391198804033
# 0.6035119700848698
# 0.5513453605951188
# 0.5187137802081261
# 0.7019780862749486
# 0.9032333333630816
# 0.6446881339005902
# 0.45419139373719924
# 0.27502363766925053
# 0.8893148326099273
# 0.8183229104114781
# 0.5355227626981465
# 0.6284483015117669
# 0.3864960848763728
# 0.46181184278113135
# 0.788909429287585
# 0.47796835098450646
# 0.2606908916977791
# 0.7157380090577885
# 0.2517392365684327
# 0.4632227310999269
# 0.5741262354144676
# 0.3188324053781908
# 0.6373996155275257
# 0.5310859997916441
# 0.33191408932105376
# 0.5148444214613609
# 0.40549036734248445
# 0.721717379349243
# 0.4912723400822707
# 0.6663180388777572
# 0.28591113794263007
# 0.5398468628769023
# 0.5646524642452123
# 0.26928792481808583
# 0.3306279640734891
# 0.620654534897372
# 0.7098081773670458
# 0.2825220327660197
# 0.3364550538905436
# 0.5781204007885855
# 0.4034713414293237
# 0.4306407987186484
# 0.41046840097242726
# 0.4085378660318015
# 0.30831147523171615
# 0.3578193868663757
# 0.41149413941908236
# 0.5347807365589252
# 0.9550093197723429
# 0.25201863509824
# 0.335802560738503
# 0.35006558430668844
# 0.36890270234711153
# 0.7605531749146706
# 0.26221348061705874
# 0.5272705495649216

# %%
# Save final sky

dest_file = "../../detectedSkies/final_skies/hr04_mbul_100_final.txt"    
result_file = open(dest_file, "a+") # the a+ allows you to create the file and write to it.

#for N, D, E, M, Q, F, H, FN in zip (det_nameR, det_distR, mstar_listR, mchirp_recR, q_recR, det_freqR, det_strainR, final_sky_file):
for N, D, E, M, Q, F, H, FN in zip (gal_name, det_dist, mstar_list, mchirp_rec, q_rec, det_freq, det_strain, final_sky_file):
    result_file.write('{0} {1} {2} {3} {4} {5} {6} {7}\n'.format(N, D, E, M, Q, F, H, FN))
result_file.close()

# %% [markdown]
# ## Evaluate this next cell at any time for nice figure formatting

# %%
fig_width_pt = 245.27 #513.17           # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inches
golden_mean = (np.sqrt(5)-1.0)/2.0      # Aesthetic ratio
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig_height =fig_width*golden_mean       # height in inches
fig_size = [fig_width,fig_height]

params = {'backend': 'pdf',
        'axes.labelsize': 7,
        'lines.markersize': 4,
        'font.size': 7,
        'xtick.major.size':6,
        'xtick.minor.size':3,  
        'ytick.major.size':6,
        'ytick.minor.size':3, 
        'xtick.major.width':0.5,
        'ytick.major.width':0.5,
        'xtick.minor.width':0.5,
        'ytick.minor.width':0.5,
        'lines.markeredgewidth':1,
        'axes.linewidth':1.2,
        'legend.fontsize': 7,
        'xtick.labelsize': 7,
        'ytick.labelsize': 7,
        'savefig.dpi':200,
        'path.simplify':True,
        'font.family': 'serif',
        'font.serif':'Times',
        'text.latex.preamble': [r'\usepackage{amsmath}'],
        'text.usetex':True,
        #'axes.color_cycle': ['b', 'lime', 'r', 'purple', 'g', 'c', 'm', 'orange', 'darkblue', \
        #                        'darkcyan', 'y','orangered','chartreuse','brown','deeppink','lightgreen', 'k'],
        #'font.serif':cm,
        'figure.figsize': fig_size}
plt.rcParams.update(params)
